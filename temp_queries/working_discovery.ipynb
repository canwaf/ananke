# %%
import pandas as pd
import hashlib
import sqlite3
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, JSON
def get_endpoint() -> str:
    """
    Fetches the endpoint used in this utility, returns the JSON type
    Returns:
        url (str): the endpoint url
    """
    sparql = SPARQLWrapper("https://staging.gss-data.org.uk/sparql")
    sparql.setReturnFormat(JSON)
    return sparql

def get_sparql(query_text: str) -> pd.DataFrame:
    """
    Queries the set SPARQL endpoint the given query_text or returns a sqlite3
    cached version. It creates a new sqlite3 database per SPARQL endpoint, and
    there is no cache expiry. If you want to fetch fresh data, delete the
    database. Soz.
    Parameters:
        query_text (str): a SPARQL query
    Returns:
        results (DataFrame): the results in a pandas DataFrame.
    """
    # Really bad caching, but I digress
    query_hex = hashlib.sha224(query_text.encode()).hexdigest()
    endpoint_hex = hashlib.sha224(get_endpoint().endpoint.encode()).hexdigest()
    # find the database connection
    con = sqlite3.connect(f"{endpoint_hex}.db")
    # check if the query_hex exists
    exist_query = f"SELECT count(*) FROM sqlite_master WHERE type='table' AND name='{query_hex}';"
    exist_result = bool(con.execute(exist_query).fetchone()[0])  # 0 = False
    if exist_result:
        # results exist so fetch results
        df = pd.read_sql(f"SELECT * FROM [{query_hex}]", con=con)
    else:
        # results don't exist in db so get them from SPARQL
        sparql = get_endpoint()
        sparql.setQuery(query_text)
        results = sparql.queryAndConvert()
        # normalise the json results
        df = pd.json_normalize(results['results']['bindings'])
        # store the results in db
        df.to_sql(query_hex, con)
        # log the query
        record = {
            "hash": [query_hex],
            "query": [query_text],
            "timestamp": [datetime.now().strftime("%Y-%m-%d %H:%M:%S")],
        }
        pd.DataFrame.from_dict(record, orient="columns").to_sql(
            "manifest", con, if_exists="append", index=False
        )
    return df

def get_datasets() -> dict:
    """
    Function to get the datasets (i.e. qb:cubes) for the SPARQL endpoint.
    Returns:
        results (DataFrame): The list of qb:Cubes on a SPARQL endpoint.
    """
    query = """PREFIX pmdcat: <http://publishmydata.com/pmdcat#>
PREFIX dcterms: <http://purl.org/dc/terms/>
# Select details regarding all datasets, assume that if there's a catalog entry
# there is an associated dataset. Might be good to check if the GRAPH exists.
SELECT ?graphUrl ?catUrl ?datasetUrl ?catTitle ?catDesc 
WHERE {
	# ?catUrl pmdcat:graph ?graphUrl ;
              dcterms:title ?catTitle ;
              dcterms:description ?catDesc ;
              pmdcat:datasetContents ?datasetUrl .
}"""
    return get_sparql(query)

def get_components(graph_uri: str):
    """
    Function to get the list qb:componentProperty for a given graph containing a qb:cube.
    Arguments:
        graph_uri (str): string URI of for the graph containing the qb:cube
    Returns:
        results (DataFrame): The components of a qb:Cube
    """
    query = f"""PREFIX qb: <http://purl.org/linked-data/cube#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# For a given cube's graph, select its components
SELECT ?graphUrl ?component ?kind ?definition
WHERE {{
    BIND(<{graph_uri}> as ?graphUrl) .
    GRAPH  ?graphUrl {{
        # ?component qb:componentProperty ?definition .
        # ?definition rdf:type ?kind .
    }}
}}"""
    return get_sparql(query)
# Compare dimensions
# Want to use urllib's object model to get the fragments of a url to find out
# things like the componentProperty type
# urllib.parse.urlparse(json_normalize(components).loc[3, 'kind.value'])
# > ParseResult(scheme='http', netloc='purl.org', path='/linked-data/cube', params='', query='', fragment='AttributeProperty')
# Also want to use urllib to extract the path, to get the dimension name

# %%
cubes = get_datasets()

# %%
cubes
# Out:
#     graphUrl.type                                     graphUrl.value  \
# 0             uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 1             uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 2             uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 3             uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 4             uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# ..            ...                                                ...
# 207           uri  http://gss-data.org.uk/graph/gss_data/homeless...
# 208           uri  http://gss-data.org.uk/graph/gss_data/homeless...
# 209           uri  http://gss-data.org.uk/graph/gss_data/homeless...
# 210           uri  http://gss-data.org.uk/graph/gss_data/energy/b...
# 211           uri  http://gss-data.org.uk/graph/gss_data/energy/b...
#
#     datasetUrl.type                                   datasetUrl.value  \
# 0               uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 1               uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 2               uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 3               uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 4               uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# ..              ...                                                ...
# 207             uri  http://gss-data.org.uk/data/gss_data/homelessn...
# 208             uri  http://gss-data.org.uk/data/gss_data/homelessn...
# 209             uri  http://gss-data.org.uk/data/gss_data/homelessn...
# 210             uri  http://gss-data.org.uk/data/gss_data/energy/be...
# 211             uri  http://gss-data.org.uk/data/gss_data/energy/be...
#
#     catUrl.type                                       catUrl.value  \
# 0           uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 1           uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 2           uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 3           uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# 4           uri  http://gss-data.org.uk/data/gss_data/covid-19/...
# ..          ...                                                ...
# 207         uri  http://gss-data.org.uk/data/gss_data/homelessn...
# 208         uri  http://gss-data.org.uk/data/gss_data/homelessn...
# 209         uri  http://gss-data.org.uk/data/gss_data/homelessn...
# 210         uri  http://gss-data.org.uk/data/gss_data/energy/be...
# 211         uri  http://gss-data.org.uk/data/gss_data/energy/be...
#
#     catDesc.xml:lang catDesc.type  \
# 0                 en      literal
# 1                 en      literal
# 2                 en      literal
# 3                 en      literal
# 4                 en      literal
# ..               ...          ...
# 207               en      literal
# 208               en      literal
# 209               en      literal
# 210               en      literal
# 211               en      literal
#
#                                          catDesc.value catTitle.xml:lang  \
# 0    A statistical report showing the impact of Cov...                en
# 1    Deaths involving coronavirus (COVID-19) in Sco...                en
# 2    Notifications to Care Inspectorate Wales of de...                en
# 3    ONS Number of deaths in care homes notified to...                en
# 4    Deaths involving COVID-19 in the care sector f...                en
# ..                                                 ...               ...
# 207  The Northern Ireland Homelessness bulletin is ...                en
# 208  The Northern Ireland Homelessness bulletin is ...                en
# 209  The Northern Ireland Homelessness bulletin is ...                en
# 210  Application statistics for the Renewable Heat ...                en
# 211  Capacity (MW) statistics for the Renewable Hea...                en
#
#     catTitle.type                                     catTitle.value
# 0         literal  Statistics relating to Covid-19 and the immigr...
# 1         literal              Deaths involving COVID-19 in Scotland
# 2         literal  Notifications of deaths of residents related t...
# 3         literal  Number of deaths in care homes notified to the...
# 4         literal  Deaths involving COVID-19 in the care sector f...
# ..            ...                                                ...
# 207       literal                    NIHE - Homelessness Acceptances
# 208       literal                  NIHE - Homelessness Presentations
# 209       literal                     NIHE - Temporary Accommodation
# 210       literal  RHI deployment data - Application Numbers, dom...
# 211       literal                RHI deployment data - Capacity (MW)
#
# [212 rows x 12 columns]

# %%
cubes.loc[19, "graphUrl.value"]
# Out:
# 'http://gss-data.org.uk/graph/gss_data/covid-19/mmo-ad-hoc-statistical-release-uk-sea-fisheries-statistics'

# %%
get_components(cubes.loc[19, "graphUrl.value"])
# Out:
#   graphUrl.type                                     graphUrl.value  \
# 0           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 1           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 2           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 3           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 4           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 5           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 6           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 7           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 8           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
#
#   component.type                                    component.value kind.type  \
# 0            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 1            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 2            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 3            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 4            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 5            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 6            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 7            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 8            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
#
#                                           kind.value definition.type  \
# 0  http://purl.org/linked-data/cube#DimensionProp...             uri
# 1  http://purl.org/linked-data/cube#DimensionProp...             uri
# 2  http://purl.org/linked-data/cube#AttributeProp...             uri
# 3  http://purl.org/linked-data/cube#DimensionProp...             uri
# 4  http://purl.org/linked-data/cube#AttributeProp...             uri
# 5  http://purl.org/linked-data/cube#DimensionProp...             uri
# 6  http://purl.org/linked-data/cube#DimensionProp...             uri
# 7  http://purl.org/linked-data/cube#DimensionProp...             uri
# 8   http://purl.org/linked-data/cube#MeasureProperty             uri
#
#                                     definition.value
# 0       http://purl.org/linked-data/cube#measureType
# 1  http://purl.org/linked-data/sdmx/2009/dimensio...
# 2  http://purl.org/linked-data/sdmx/2009/attribut...
# 3  http://purl.org/linked-data/sdmx/2009/dimensio...
# 4  http://purl.org/linked-data/sdmx/2009/attribut...
# 5  http://gss-data.org.uk/data/gss_data/covid-19/...
# 6  http://gss-data.org.uk/data/gss_data/covid-19/...
# 7  http://gss-data.org.uk/data/gss_data/covid-19/...
# 8          http://gss-data.org.uk/def/measure/weight

# %%
components = get_components(cubes.loc[19, "graphUrl.value"])

# %%
url = components.loc[3, "kind.value"]

# %%
url
# Out:
# 'http://purl.org/linked-data/cube#DimensionProperty'

# %%
from urllib.parse import urlparse

# %%
urlparse(url)
# Out:
# ParseResult(scheme='http', netloc='purl.org', path='/linked-data/cube', params='', query='', fragment='DimensionProperty')

# %%
urlparse(url).fragment
# Out:
# 'DimensionProperty'

# %%
components['kind.value'].apply(lambda x: urlparse(x).fragment)
# Out:
# 0    DimensionProperty
# 1    DimensionProperty
# 2    AttributeProperty
# 3    DimensionProperty
# 4    AttributeProperty
# 5    DimensionProperty
# 6    DimensionProperty
# 7    DimensionProperty
# 8      MeasureProperty
# Name: kind.value, dtype: object

# %%
components['definition.value'].apply(lambda x: urlparse(x).fragment)
# Out:
# 0                measureType
# 1                  refPeriod
# 2                unitMeasure
# 3                    refArea
# 4                  obsStatus
# 5    dimension/vessel-length
# 6    dimension/species-group
# 7       dimension/admin-port
# 8
# Name: definition.value, dtype: object

# %%
components['definition.value']
# Out:
# 0         http://purl.org/linked-data/cube#measureType
# 1    http://purl.org/linked-data/sdmx/2009/dimensio...
# 2    http://purl.org/linked-data/sdmx/2009/attribut...
# 3    http://purl.org/linked-data/sdmx/2009/dimensio...
# 4    http://purl.org/linked-data/sdmx/2009/attribut...
# 5    http://gss-data.org.uk/data/gss_data/covid-19/...
# 6    http://gss-data.org.uk/data/gss_data/covid-19/...
# 7    http://gss-data.org.uk/data/gss_data/covid-19/...
# 8            http://gss-data.org.uk/def/measure/weight
# Name: definition.value, dtype: object

# %%
components.loc[6, 'definition.value']
# Out:
# 'http://gss-data.org.uk/data/gss_data/covid-19/mmo-ad-hoc-statistical-release-uk-sea-fisheries-statistics#dimension/species-group'

# %%
components['definition.value'].apply(lambda x: urlparse(x).fragment)
# Out:
# 0                measureType
# 1                  refPeriod
# 2                unitMeasure
# 3                    refArea
# 4                  obsStatus
# 5    dimension/vessel-length
# 6    dimension/species-group
# 7       dimension/admin-port
# 8
# Name: definition.value, dtype: object

# %%
components['kind.value'].apply(lambda x: urlparse(x).fragment)
# Out:
# 0    DimensionProperty
# 1    DimensionProperty
# 2    AttributeProperty
# 3    DimensionProperty
# 4    AttributeProperty
# 5    DimensionProperty
# 6    DimensionProperty
# 7    DimensionProperty
# 8      MeasureProperty
# Name: kind.value, dtype: object

# %%
components.loc[components['kind.value'].apply(lambda x: urlparse(x).fragment) == 'DimensionProperty']
# Out:
#    index graphUrl.type                                     graphUrl.value  \
# 0      0           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 1      1           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 3      3           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 5      5           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 6      6           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
# 7      7           uri  http://gss-data.org.uk/graph/gss_data/covid-19...
#
#   component.type                                    component.value kind.type  \
# 0            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 1            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 3            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 5            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 6            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
# 7            uri  http://gss-data.org.uk/data/gss_data/covid-19/...       uri
#
#                                           kind.value definition.type  \
# 0  http://purl.org/linked-data/cube#DimensionProp...             uri
# 1  http://purl.org/linked-data/cube#DimensionProp...             uri
# 3  http://purl.org/linked-data/cube#DimensionProp...             uri
# 5  http://purl.org/linked-data/cube#DimensionProp...             uri
# 6  http://purl.org/linked-data/cube#DimensionProp...             uri
# 7  http://purl.org/linked-data/cube#DimensionProp...             uri
#
#                                     definition.value
# 0       http://purl.org/linked-data/cube#measureType
# 1  http://purl.org/linked-data/sdmx/2009/dimensio...
# 3  http://purl.org/linked-data/sdmx/2009/dimensio...
# 5  http://gss-data.org.uk/data/gss_data/covid-19/...
# 6  http://gss-data.org.uk/data/gss_data/covid-19/...
# 7  http://gss-data.org.uk/data/gss_data/covid-19/...

# %%
urlparse(components.loc[8, 'definition.value']).fragment
# Out:
# ''

# %%
type(urlparse(components.loc[8, 'definition.value']).fragment)
# Out:
# str

# %%
len(urlparse(components.loc[8, 'definition.value']).fragment)
# Out:
# 0

# %%
from urllib.parse import urlparse
def fetch_fragment(url: str) -> str:
    """ Function to parse a url when you can't depend on the fragment
    being the component of the property you want.
    Parameters:
        url (str): the url you want to parse
    Returns:
        fragment (str): the final part of a parsed url
    """
    parsed = urlparse(url)
    if len(parsed.fragment) == 0:
        return parsed.path.split("/")[-1]
    elif "/" in parsed.fragment:
        return parsed.fragment.split("/")[-1]
    else:
        return parsed.fragment

# %%
fetch_fragment(components.loc[8, 'definition.value'])
# Out:
# 'weight'

# %%
components['definition.value'].apply(lambda x: fetch_fragment(x))
# Out:
# 0      measureType
# 1        refPeriod
# 2      unitMeasure
# 3          refArea
# 4        obsStatus
# 5    vessel-length
# 6    species-group
# 7       admin-port
# 8           weight
# Name: definition.value, dtype: object

# %%
components['kind.value'].apply(lambda x: fetch_fragment(x))
# Out:
# 0    DimensionProperty
# 1    DimensionProperty
# 2    AttributeProperty
# 3    DimensionProperty
# 4    AttributeProperty
# 5    DimensionProperty
# 6    DimensionProperty
# 7    DimensionProperty
# 8      MeasureProperty
# Name: kind.value, dtype: object

# %%
def get_fragment(url: str) -> str:
    """Function to parse a url when you can't depend on the fragment
    being the component of the property you want.
    Parameters:
        url (str): the url you want to parse
    Returns:
        fragment (str): the final part of a parsed url
    """
    parsed = urlparse(url)
    if len(parsed.fragment) == 0:
        return parsed.path.split("/")[-1]
    elif "/" in parsed.fragment:
        return parsed.fragment.split("/")[-1]
    else:
        return parsed.fragment

# %%
components.loc[
        components["kind.value"].apply(lambda x: get_fragment(x))
        == "DimensionProperty",
        "definition.value",
    ]
# Out:
# 0         http://purl.org/linked-data/cube#measureType
# 1    http://purl.org/linked-data/sdmx/2009/dimensio...
# 3    http://purl.org/linked-data/sdmx/2009/dimensio...
# 5    http://gss-data.org.uk/data/gss_data/covid-19/...
# 6    http://gss-data.org.uk/data/gss_data/covid-19/...
# 7    http://gss-data.org.uk/data/gss_data/covid-19/...
# Name: definition.value, dtype: object

# %%
type(components.loc[
        components["kind.value"].apply(lambda x: get_fragment(x))
        == "DimensionProperty",
        "definition.value",
    ])
# Out:
# pandas.core.series.Series

# %%
components.loc[
        components["kind.value"].apply(lambda x: get_fragment(x))
        == "DimensionProperty",
        "definition.value",
    ].apply(lambda x: get_fragment(x))
# Out:
# 0      measureType
# 1        refPeriod
# 3          refArea
# 5    vessel-length
# 6    species-group
# 7       admin-port
# Name: definition.value, dtype: object

# %%
list(components.loc[
        components["kind.value"].apply(lambda x: get_fragment(x))
        == "DimensionProperty",
        "definition.value",
    ].apply(lambda x: get_fragment(x)))
# Out:
# ['measureType',
#  'refPeriod',
#  'refArea',
#  'vessel-length',
#  'species-group',
#  'admin-port']
